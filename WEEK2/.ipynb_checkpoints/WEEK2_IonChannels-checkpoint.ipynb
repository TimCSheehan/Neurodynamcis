# %%
## Example code for BENG 260 Homework 2, Fall 2017
## Questions to vramesh@eng.ucsd.edu or gert@ucsd.edu

import scipy as sp
import pylab as plt
from scipy.integrate import odeint
import numpy as np
import random

# %%
# Problem 1b
# compute Tau from -100:100

A0 = 0.7
B0 = 0.9
LAM = MU = .01
t_input = 8
t_step = .01
t = np.arange(0,16,t_step)
t_tau = np.arange(-100,101,1)
Vm = np.zeros(len(t))
Vm[t>8] = 30
Vm_tau = np.zeros(len(t_tau))

Vm_tau[t_tau>t_input] = 30
An_tau = A0*np.exp(LAM*Vm_tau)
Bn_tau = B0*np.exp(-MU*Vm_tau)

An = A0*np.exp(LAM*Vm)
Bn = B0*np.exp(-MU*Vm)

def An_f(Vm):
    return A0*np.exp(LAM*Vm)
def Bn_f(Vm):
    return B0*np.exp(-MU*Vm)

Tau = 1/(An_tau+Bn_tau)
plt.plot(t_tau,Tau)
plt.xlabel('Time (s)')
plt.ylabel('Tau (s)')

#plt.savefig('Part1b.png')
plt.show()

# %%
# problem 1b
def dndt(n, t):
    if t>8:
        Vm = 30
    else:
        Vm = 0
    return An_f(Vm)*(1-n) - Bn_f(Vm)*n
n_t = odeint(dndt,0,t)*100
plt.plot(t,n_t)
plt.xlabel('Time (s)')
plt.ylabel('% of Channels Open')
#plt.savefig('Part1c.png')
plt.show()

# %%
# t_step = .1
# t = np.arange(0,16,t_step)
def n_t_markov(N):
#N = 1000 #- # of gates
    gates = np.zeros(N)
    n_open = np.zeros(len(t))

    for t_ind in range(len(t)):
        for gate_i in range(N):
            prob_sample = random.uniform(0,1)
            if gates[gate_i] == 0:
                gates[gate_i] = prob_sample < (t_step*An_f(Vm[t_ind]))
            else:
                gates[gate_i] = prob_sample < (1-t_step*Bn_f(Vm[t_ind]))
        n_open[t_ind] = np.mean(gates)*100
    return n_open

# %%
n_open_1 = n_t_markov(1)
n_open_400 = n_t_markov(400)
n_open_1000 = n_t_markov(1000)

# %%
plt.plot(n_open_1,label = 'N=1')
plt.plot(n_open_400,label = 'N=400')
plt.plot(n_open_1000,label = 'N=1000')
plt.legend(loc=2)
plt.xlabel('Time (s)')
plt.ylabel('% of Channels Open')
plt.title('Markov Chain')
#plt.savefig('Part1d_1.png')
plt.show()

# %%
plt.plot(n_t,label='Analytic')
plt.plot(n_open_1000,label='Markov')
plt.xlabel('Time (s)')
plt.ylabel('% of Channels Open')
plt.legend()
#plt.savefig('Part1d_2.png')
plt.show()

# %%
###########################################################
## Problem 2: Morris-Lecar (barnacle muscle fiber) Model ##
###########################################################
# Constants
C_m  =   1.0 # membrane capacitance, in uF/cm^2
g_Ca =   1.1 # maximum conducances, in mS/cm^2
g_K  =   36
g_L  =   0.3
g_Na =   120
E_Ca = 100.0 # Nernst reversal potentials, in mV
E_K  = -12.0
E_L  = 10.613
E_Na = 115
# Channel gating kinetics
# Functions of membrane voltage
def m_infty(V): return (1.0 + sp.tanh((V + 1.0) / 15.0)) / 2.0
def w_infty(V): return (1.0 + sp.tanh(V / 30.0)) / 2.0
def tau_w(V):   return 5.0 / sp.cosh(V / 60.0)  # in ms

# Membrane currents (in uA/cm^2)
def I_Ca(V):    return g_Ca * m_infty(V) * (V - E_Ca)
def I_K(V, w):  return g_K  * w          * (V - E_K)
def I_L(V):     return g_L               * (V - E_L)

# External current
# step up 10 uA/cm^2 every 100ms
def I_ext(t): return 10*sp.floor(t/100)+10

# The time to integrate over and the overall current trace
t = sp.arange(0.0, 400.0, 0.1)
I = I_ext(t)

# %%
def a_m(V): return (25-V)/(10*(np.exp((25-V)/10)-1))
def b_m(V): return 4*np.exp(-V/18)
def a_h(V): return 0.07*np.exp(-V/20)
def b_h(V): return 1/(np.exp((30-V)/10)+1)
def a_n(V): return (10-V)/(100*(np.exp((10-V)/10)-1))
def b_n(V): return 0.125*np.exp(-V/80)

# %%
V = np.arange(-20,121,1)
plt
plt.subplot(3,2,1)
plt.plot(V,a_m(V),label='a_m')
plt.xlabel('V_m (mV)')
plt.ylabel('Rate')
plt.title('a_m')

plt.subplot(3,2,2)
plt.plot(V,b_m(V),label='b_m')
plt.title('b_m')

plt.subplot(3,2,3)
plt.plot(V,a_h(V),label='a_h')
# plt.xlabel('V_m (mV)')
plt.title('a_h')

plt.subplot(3,2,4)
plt.plot(V,b_h(V),label='b_h')
plt.title('b_h')

plt.subplot(3,2,5)
plt.plot(V,a_n(V),label='a_n')
plt.title('a_n')

plt.subplot(3,2,6)
plt.plot(V,b_n(V),label='b_n')
plt.title('b_n')
plt.xlabel('V_m (mV)')
plt.show()
# Out:
# /Users/sheehantc/miniconda3/envs/py_run/lib/python3.6/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':
# /Users/sheehantc/miniconda3/envs/py_run/lib/python3.6/site-packages/ipykernel/__main__.py:5: RuntimeWarning: invalid value encountered in true_divide

# %%
########################################
## Problem 2.2: leaky passive neuron
def dVdt_leak(V, t): return (I_ext(t) - I_L(V)) / C_m
V_leak = odeint(dVdt_leak, E_L, t)

plt.figure()

plt.subplot(2,1,1)
plt.title('2.2: Leaky Passive Neuron')
plt.plot(t, V_leak, 'k')
plt.ylabel('V (mV)')

plt.subplot(2,1,2)
plt.plot(t, I, 'k')
plt.xlabel('t (ms)')
plt.ylabel('$I_{ext}$ ($\\mu{A}/cm^2$)')
plt.ylim(-1, I[len(I)-1]+1)

plt.show()

# %%
# 2d
# initialize



def Vm_dynamics(I_E):
    l_t = len(t)
    m_t = np.zeros(l_t)
    n_t = np.zeros(l_t)
    h_t = np.zeros(l_t)
    v_t = np.zeros(l_t)
    # starting values
    v_t[0] = 0
    m_t[0] = a_m(v_t[0])/(a_m(v_t[0]) + b_m(v_t[0]))
    h_t[0] = a_h(v_t[0])/(a_h(v_t[0]) + b_h(v_t[0]))
    n_t[0] = a_n(v_t[0])/(a_n(v_t[0]) + b_n(v_t[0]))
    for i in range(l_t-1):

        t_i = i+1
        v_i = v_t[i]

        m_t[t_i] = (a_m(v_i)*(1-m_t[i])-b_m(v_i)*m_t[i])*t_step+m_t[i]
        n_t[t_i] = (a_n(v_i)*(1-n_t[i])-b_n(v_i)*n_t[i])*t_step+n_t[i]
        h_t[t_i] = (a_h(v_i)*(1-h_t[i])-b_h(v_i)*h_t[i])*t_step+h_t[i]

        I_NA = g_Na*m_t[t_i]**3*h_t[t_i]*(v_i-E_Na)
        I_K = g_K*n_t[t_i]**4*(v_i-E_K)
        I_L = g_L*(v_i-E_L)

        v_t[t_i] = (1/C_m*(-I_NA-I_K-I_L+I_E))*t_step+v_i
    return v_t

# %%
v_t_10 = Vm_dynamics(10)
v_t_5 = Vm_dynamics(5)
v_t_20 = Vm_dynamics(20)
v_t_30 = Vm_dynamics(30)

plt.plot(t,v_t_5)
plt.title('I_ext = 5uA/cm2')
plt.xlabel('Time (s)')
plt.ylabel('V_m (mV)')
plt.show()

plt.plot(t,v_t_10)
plt.title('I_ext = 10uA/cm2')
plt.xlabel('Time (s)')
plt.ylabel('V_m (mV)')
plt.show()

plt.plot(t,v_t_20)
plt.title('I_ext = 20uA/cm2')
plt.xlabel('Time (s)')
plt.ylabel('V_m (mV)')
plt.show()

# %%
# Out:
# 0.31767691406069742

# %%
########################################
## Problem 2.3: Morris-Lecar neuron
def dALLdt(X,t):
    V, w = X
    dVdt = (I_ext(t) - I_Ca(V) - I_K(V, w) - I_L(V)) / C_m
    dwdt = (w_infty(V) - w) / tau_w(V)
    return dVdt, dwdt

# Call the odeint, giving 2 initial conditions, for V and w, in the same order as everything else
X = odeint(dALLdt, [-44, 0.05], t)

V = X[:,0] # the first column is the V values
w = X[:,1] # the second column is the w values

plt.figure()

plt.subplot(3,1,1)
plt.title('2.3: Morris-Lecar Neuron')
plt.plot(t, V, 'k')
plt.ylabel('V (mV)')

plt.subplot(3,1,2)
# recommended style: use the came colors as you did in part 2.1
plt.plot(t, w, 'g', label='w')
plt.ylabel('Gating Value')
plt.legend()

plt.subplot(3,1,3)
plt.plot(t, I_ext(t), 'k')
plt.xlabel('t (ms)')
plt.ylabel('$I_{ext}$ ($\\mu{A}/cm^2$)')
plt.ylim(-1, I[len(I)-1]+1)

plt.show()

# %%
###########################################################################
## Problem 4: Morris-Lecar model with expanded channel gating dynamics   ##
###########################################################################
# Constants
C_m  = 1.0      # membrane capacitance, in uF/cm^2
g_Ca = 1.1      # maximum conducances, in mS/cm^2
g_K  = 2.0 
g_L  = 0.5 
E_Ca = 100      # Nernst reversal potentials, in mV
E_K  = -70 
E_L  = -50 

# Channel gating kinetics
# Functions of membrane voltage
def m_infty(V): return (1 + tanh((V + 1) / 15)) / 2
def w_infty(V): return (1 + tanh(V / 30)) / 2
def tau_w(V): return 5 / cosh(V / 60)              # in ms

# Membrane currents (in uA/cm^2)
def I_Ca(V): return g_Ca * m_infty(V) * (V - E_Ca)
def I_K(V, w): return g_K * w * (V - E_K)
def I_L(V): return g_L * (V - E_L)
def I_ext(t): return 40+floor(t/20)

t_start = 0
t_stop = 200
t_step = 0.1
t = sp.arange(t_start, t_stop, t_step)

# %%
##################################%
# 4.1 Linear solution (ODE solver)
##################################%
# Differential equation for X(1)=Vm and X(2)=w
def dXdt(X,t):
    V, w = X
    dVdt = (I_ext(t) - I_Ca(V) - I_K(V, w) - I_L(V)) / C_m
    dwdt = (w_infty(V) - w) / tau_w(V)
    return dVdt, dwdt

X = odeint(dXdt, [-70, 0], t)

Vm_linear = X[:,0] # the first column is the V values
w_linear  = X[:,1] # the second column is the w values

plot(t, Vm_linear)
plot(t, w_linear)
plot(t, I_ext(t))

# %%
###################################
## 4.2 Stochastic solution (Markov)
###################################
def alpha_w(Vm): return w_infty(Vm) / tau_w(Vm)
def beta_w(Vm): return (1/tau_w(Vm)) - alpha_w(Vm)

N = 5000                      # number of gates
gates = zeros((N))            # all gates start in state 0
Vm_stoch = zeros(size(t))     # store Vm
w_stoch = zeros(size(t))      # store the fraction of gates open

Vm_current = -70
w_current = 0

for t_index in range(0,len(t)):

    # ODE solver
    def dVdt(Vm, t):
        return (I_ext(t) - I_Ca(Vm) - I_K(Vm, w_current) - I_L(Vm)) / C_m
    Vm = odeint(dVdt, Vm_current, sp.arange(t[t_index],t[t_index]+t_step,t_step/10))

    Vm_current = Vm[-1]
    Vm_stoch[t_index] = Vm_current
    
    for gate_index in range(0,len(gates)):
        prob_sample = rand()        # probabilistic sample
        if gates[gate_index]==0:
            # transition from state 0->1
            gates[gate_index] = prob_sample < t_step*alpha_w(Vm_current);
        else:
            # remain in state 1
            gates[gate_index] = prob_sample < (1-t_step*beta_w(Vm_current));

    w_current = sum(gates)/N
    w_stoch[t_index] = w_current

plot(t, Vm_stoch)
show()
plot(t, w_stoch)
